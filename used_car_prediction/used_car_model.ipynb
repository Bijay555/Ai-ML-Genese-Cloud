# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('used_car_data.csv')
df.head()
# Out:
#        Brand    Model  Model_year Transmission  Engine_size(cc) Drivetrain  \
# 0  Chevrolet     aveo      2009.0       Manual           1150.0        2WD
# 1  Chevrolet  captiva      2015.0    Automatic           2000.0        4WD
# 2  Chevrolet     aveo      2009.0       Manual           1150.0        2WD
# 3  Chevrolet  captiva      2010.0    Automatic           2000.0        4WD
# 4  Chevrolet    spark      2012.0       Manual           1000.0        2WD
#
#   Fuel_type      Colour  Lot_no  Kilometer Status        Price
# 0    Petrol      golden     6.0      200.0   USED   Rs. 975000
# 1    Diesel        Grey     8.0      100.0   USED  Rs. 3000000
# 2    Petrol      golden     6.0    42000.0   USED   Rs. 975000
# 3    Diesel        Grey     8.0    51000.0   USED  Rs. 3000000
# 4    Petrol   Sky Blue      9.0    38000.0   USED  Rs. 1000000

# %%
df.shape
# Out:
# (2217, 12)

# %%
df['Status'].unique()
# Out:
# array(['USED', nan], dtype=object)

# %% [markdown]
# #####  Since we know that the vehicles are used vehicle so this column 'Status' has no use.

# %%
df.drop(['Status'], axis='columns', inplace=True)

# %%
df.head()
# Out:
#        Brand    Model  Model_year Transmission  Engine_size(cc) Drivetrain  \
# 0  Chevrolet     aveo      2009.0       Manual           1150.0        2WD
# 1  Chevrolet  captiva      2015.0    Automatic           2000.0        4WD
# 2  Chevrolet     aveo      2009.0       Manual           1150.0        2WD
# 3  Chevrolet  captiva      2010.0    Automatic           2000.0        4WD
# 4  Chevrolet    spark      2012.0       Manual           1000.0        2WD
#
#   Fuel_type      Colour  Lot_no  Kilometer        Price
# 0    Petrol      golden     6.0      200.0   Rs. 975000
# 1    Diesel        Grey     8.0      100.0  Rs. 3000000
# 2    Petrol      golden     6.0    42000.0   Rs. 975000
# 3    Diesel        Grey     8.0    51000.0  Rs. 3000000
# 4    Petrol   Sky Blue      9.0    38000.0  Rs. 1000000

# %%
df.isnull().sum()
# Out:
# Brand              316
# Model              316
# Model_year         316
# Transmission       316
# Engine_size(cc)    316
# Drivetrain         316
# Fuel_type          316
# Colour             316
# Lot_no             316
# Kilometer          316
# Price              316
# dtype: int64

# %%
cols=['Brand','Model','Model_year','Transmission','Engine_size(cc)','Drivetrain','Fuel_type','Colour','Lot_no','Kilometer','Price']
cols
# Out:
# ['Brand',
#  'Model',
#  'Model_year',
#  'Transmission',
#  'Engine_size(cc)',
#  'Drivetrain',
#  'Fuel_type',
#  'Colour',
#  'Lot_no',
#  'Kilometer',
#  'Price']

# %% [markdown]
# ###### There are equal no of missing values in all columns of the dataset. But when I see the dataset I found that these are not missing values but empty rows thatswhy all mising values are equal so we remove the these empty rows.

# %%
df.replace('',np.nan, inplace=True)
df.tail()
# Out:
#            Brand   Model  Model_year Transmission  Engine_size(cc) Drivetrain  \
# 2212  Volkswagen  passat      2010.0       Manual           1800.0        2WD
# 2213         NaN     NaN         NaN          NaN              NaN        NaN
# 2214  Volkswagen  tiguan      2010.0       Manual           2000.0        2WD
# 2215         NaN     NaN         NaN          NaN              NaN        NaN
# 2216  Volkswagen   vento      2012.0       Manual           1600.0        2WD
#
#      Fuel_type       Colour  Lot_no  Kilometer        Price
# 2212    Petrol        black     8.0    11000.0  Rs. 5800000
# 2213       NaN          NaN     NaN        NaN          NaN
# 2214    Petrol   India blue     8.0    25000.0  Rs. 4900000
# 2215       NaN          NaN     NaN        NaN          NaN
# 2216    Diesel       Silver    11.0    14000.0  Rs. 3555555

# %%
df.dropna(subset=cols,inplace=True)
df.tail()
# Out:
#            Brand   Model  Model_year Transmission  Engine_size(cc) Drivetrain  \
# 2210  Volkswagen    polo      2013.0       Manual           1600.0        2WD
# 2211  Volkswagen  beetle      2010.0       Manual           1595.0        2WD
# 2212  Volkswagen  passat      2010.0       Manual           1800.0        2WD
# 2214  Volkswagen  tiguan      2010.0       Manual           2000.0        2WD
# 2216  Volkswagen   vento      2012.0       Manual           1600.0        2WD
#
#      Fuel_type       Colour  Lot_no  Kilometer        Price
# 2210    Petrol      Silver     11.0     6300.0  Rs. 2700000
# 2211    Petrol   Maroon Red     8.0    19000.0  Rs. 3950000
# 2212    Petrol        black     8.0    11000.0  Rs. 5800000
# 2214    Petrol   India blue     8.0    25000.0  Rs. 4900000
# 2216    Diesel       Silver    11.0    14000.0  Rs. 3555555

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1901 entries, 0 to 2216
# Data columns (total 11 columns):
# Brand              1901 non-null object
# Model              1901 non-null object
# Model_year         1901 non-null float64
# Transmission       1901 non-null object
# Engine_size(cc)    1901 non-null float64
# Drivetrain         1901 non-null object
# Fuel_type          1901 non-null object
# Colour             1901 non-null object
# Lot_no             1901 non-null float64
# Kilometer          1901 non-null float64
# Price              1901 non-null object
# dtypes: float64(4), object(7)
# memory usage: 178.2+ KB

# %%
df['Brand'].unique()
# Out:
# array(['Chevrolet', 'Fiat', 'Ford', 'Honda', 'Hyundai', 'Kia',
#        'Land Rover', 'Mahindra', 'Maruti Suzuki', 'Nissan', 'Skoda',
#        'Tata', 'Toyota', 'Volkswagen'], dtype=object)

# %%
df['Model'].unique()
# Out:
# array(['aveo', 'captiva', 'spark', 'beat', 'u-va', 'uva', 'sedan',
#        'avventura', 'punto', 'linea', 'figo', 'palio', 'ecosport',
#        'titanium', 'fiesta', 'ranger', 'cr-v', 'city', 'jazz', 'brio',
#        'civic', 'crv', 'accent', 'i10', 'santro', 'i20', 'getz', 'asta',
#        'tucson', 'eon', 'creta', 'elite', 'elantra', 'sonata', 'sephia',
#        'sportage', 'picanto', 'rio', 'soul', 'carens', 'cerato',
#        'freelander', 'discovery', 'defender', 'bolero', 'Kuv', 'scorpio',
#        'swift', 'alto-800', 'celerio', 'alto-LXI', 'Omni', '800', 'eeco',
#        'astar', 'alto', 'dzire', 'a-star', 'saloon', 'sunny', 'tiida',
#        'fabia', 'laura', 'rapid', 'superb', 'octavia', 'sumo', 'safari',
#        'ace', 'indica', 'bolt', 'strome', 'nano', 'grande', 'manza',
#        'venture', 'indigo', 'corolla', 'fortuner', 'hilux', 'cruiser',
#        'etios', 'echo', 'avanza', 'camry', 'corona', 'prado', 'hiace',
# ...

# %%
df['Transmission'].unique()
# Out:
# array([' Manual', ' Automatic'], dtype=object)

# %%
df['Transmission']=df['Transmission'].replace([' Manual',' Automatic'], [0,1])

# %%
df['Transmission'].head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    1
# 4    0
# Name: Transmission, dtype: int64

# %%
df['Transmission']=df['Transmission'].astype(int)

# %%
df['Drivetrain'].unique()
# Out:
# array([' 2WD', ' 4WD'], dtype=object)

# %%
df['Drivetrain']=df['Drivetrain'].replace([' 2WD',' 4WD'], [0,1])

# %%
df['Drivetrain'].head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    1
# 4    0
# Name: Drivetrain, dtype: int64

# %%
df['Fuel_type'].unique()
# Out:
# array([' Petrol', ' Diesel'], dtype=object)

# %%
df['Fuel_type']=df['Fuel_type'].replace([' Petrol', ' Diesel'],[0,1])

# %%
df['Fuel_type'].head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    1
# 4    0
# Name: Fuel_type, dtype: int64

# %%
df['Colour'].unique()
# Out:
# array([' golden', ' Grey', ' Sky Blue ', ' Green', ' Red/Maroon',
#        ' Maroon', ' royal black', ' metalic sky blue', ' Golden Silver ',
#        ' Red', ' Lilene Beige', ' White', ' Bue', ' Light Golden',
#        ' Silver', ' Sky blue', ' golden silver', ' silver', ' Metallic',
#        ' Golden', ' Gray', ' Black', ' WHITE', ' Platinum Metallic',
#        ' Dark Gray', ' Blue', ' black', ' Chocolate Grey',
#        ' Caviar Black ', ' SILVER', ' white ', '  Pearl Silver',
#        ' orange ', ' Velvet Red', ' Beige', ' sky blue', ' Caviar Black',
#        ' Lenin Beige', ' Sandive grey', ' Silver ', ' Cream Blue',
#        ' Off white ', ' dark grey', ' maroon(red)', ' White ',
#        ' Golden Grey', ' Moondust Silver', ' Mars Red', ' smoke grey',
#        ' White Gold', ' Orange', ' Chilly Silver ', ' grey', ' white',
#        ' Sea greay', ' Space gray', ' FROGEN WHITE', ' Paprika Red',
#        ' Chill', ' Sea gray ', ' Sea Grey', ' Siver', ' Diamond white',
# ...

# %% [markdown]
# ##### Actually color has no role in determining the price of the car so I am removing the 'Colour' column

# %%
df.drop(['Colour'],axis='columns',inplace=True)

# %%
df.isnull().sum()
# Out:
# Brand              0
# Model              0
# Model_year         0
# Transmission       0
# Engine_size(cc)    0
# Drivetrain         0
# Fuel_type          0
# Lot_no             0
# Kilometer          0
# Price              0
# dtype: int64

# %%
df.head()
# Out:
#        Brand    Model  Model_year  Transmission  Engine_size(cc)  Drivetrain  \
# 0  Chevrolet     aveo      2009.0             0           1150.0           0
# 1  Chevrolet  captiva      2015.0             1           2000.0           1
# 2  Chevrolet     aveo      2009.0             0           1150.0           0
# 3  Chevrolet  captiva      2010.0             1           2000.0           1
# 4  Chevrolet    spark      2012.0             0           1000.0           0
#
#    Fuel_type  Lot_no  Kilometer        Price
# 0          0     6.0      200.0   Rs. 975000
# 1          1     8.0      100.0  Rs. 3000000
# 2          0     6.0    42000.0   Rs. 975000
# 3          1     8.0    51000.0  Rs. 3000000
# 4          0     9.0    38000.0  Rs. 1000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1901 entries, 0 to 2216
# Data columns (total 10 columns):
# Brand              1901 non-null object
# Model              1901 non-null object
# Model_year         1901 non-null float64
# Transmission       1901 non-null int32
# Engine_size(cc)    1901 non-null float64
# Drivetrain         1901 non-null int64
# Fuel_type          1901 non-null int64
# Lot_no             1901 non-null float64
# Kilometer          1901 non-null float64
# Price              1901 non-null object
# dtypes: float64(4), int32(1), int64(2), object(3)
# memory usage: 155.9+ KB

# %% [markdown]
# ###### Price column has 'Rs' in every row so we remove it

# %%
df['Price'] = (df['Price'].str.strip('Rs. ').astype(int))
df['Price'].head()
# Out:
# 0     975000
# 1    3000000
# 2     975000
# 3    3000000
# 4    1000000
# Name: Price, dtype: int32

# %%
df[['Transmission','Kilometer','Price']] = df[['Transmission','Kilometer','Price']].apply(pd.to_numeric)
df.dtypes
# Out:
# Brand               object
# Model               object
# Model_year         float64
# Transmission         int32
# Engine_size(cc)    float64
# Drivetrain           int64
# Fuel_type            int64
# Lot_no             float64
# Kilometer          float64
# Price                int32
# dtype: object

# %%
df['Price'].head()
# Out:
# 0     975000
# 1    3000000
# 2     975000
# 3    3000000
# 4    1000000
# Name: Price, dtype: int32

# %%
from sklearn.preprocessing import StandardScaler

df1= StandardScaler().fit_transform(df)
df1
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int32, int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype int32, int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# array([[-0.1073269 , -0.20406821, -0.53252521, ..., -0.4924263 ,
#         -0.70265728, -1.06415813],
#        [ 1.35699203,  4.90032222,  1.14263757, ...,  2.03076075,
#         -0.0820991 , -1.06676031],
#        [-0.1073269 , -0.20406821, -0.53252521, ..., -0.4924263 ,
#         -0.70265728,  0.02355238],
#        ...,
#        [ 0.13672625, -0.20406821,  0.74848162, ..., -0.4924263 ,
#         -0.0820991 , -0.78312288],
#        [ 0.13672625, -0.20406821,  1.14263757, ..., -0.4924263 ,
#         -0.0820991 , -0.41881792],
# ...

# %%
cols1=['Transmission','Engine_size(cc)','Drivetrain','Fuel_type','Lot_no','Kilometer','Price']
cols1
# Out:
# ['Transmission',
#  'Engine_size(cc)',
#  'Drivetrain',
#  'Fuel_type',
#  'Lot_no',
#  'Kilometer',
#  'Price']

# %%
df2 = pd.DataFrame(data=df1, columns=cols1)
df2.head()
# Out:
#    Transmission  Engine_size(cc)  Drivetrain  Fuel_type    Lot_no  Kilometer  \
# 0     -0.107327        -0.204068   -0.532525  -0.357100 -0.492426  -0.702657
# 1      1.356992         4.900322    1.142638   2.800332  2.030761  -0.082099
# 2     -0.107327        -0.204068   -0.532525  -0.357100 -0.492426  -0.702657
# 3      0.136726         4.900322    1.142638   2.800332  2.030761  -0.082099
# 4      0.624833        -0.204068   -0.828142  -0.357100 -0.492426   0.228180
#
#       Price
# 0 -1.064158
# 1 -1.066760
# 2  0.023552
# 3  0.257748
# 4 -0.080535

# %%
fig = plt.subplots(figsize = (10,13))
sns.set(font_scale=1.5)
sns.heatmap(df.corr(),square = True,cbar=True,annot=True,annot_kws={'size': 10})
plt.show()

# %% [markdown]
# ###### Kilometer is negatively corelated which make sense as less the car kilometer covered more its price. With engine,drivetrain, fuel_type,lot_no, transmission and model_year, the price is positively corelated

# %% [markdown]
# ###### model_year and lot_no is highly corelated and engine and drivetrain are also highly corelated

# %% [markdown]
# ###### while kilometer and lot_no is negatively corelated which make sense because more kilometer means car is old and has older lot_no.

# %%
# Plot the two variables against eachother
df.plot(x='Engine_size(cc)', y='Price', kind='scatter')

# %% [markdown]
# ##### As the engine size(cc) increases price also increases

# %%
# Plot the two variables against eachother
df.plot(x='Kilometer', y='Price', kind='scatter')

# %%
df.boxplot(column='Price', by='Engine_size(cc)',figsize=(15,10))

# %%
df.boxplot(column='Kilometer', by='Lot_no',figsize=(15,10))

# %%
sns.pairplot(df)

# %% [markdown]
# ###### Lot of insight can be gather from the above figure like
# + new lot no car has more price
# + less kilometer covered car has more price
# + recent model car has high price
# + new model car has less kilometer covered and new lot no

# %%
df.hist(figsize=(10,12), color='#86bf91') # plot histogram
plt.suptitle("Histogram", fontsize=10) # use suptitle to add title to all
plt.show()

# %%
y=df['Price']
df.drop(['Price'], axis='columns', inplace=True)
df.head()
# Out:
#        Brand    Model  Model_year  Transmission  Engine_size(cc)  Drivetrain  \
# 0  Chevrolet     aveo      2009.0             0           1150.0           0
# 1  Chevrolet  captiva      2015.0             1           2000.0           1
# 2  Chevrolet     aveo      2009.0             0           1150.0           0
# 3  Chevrolet  captiva      2010.0             1           2000.0           1
# 4  Chevrolet    spark      2012.0             0           1000.0           0
#
#    Fuel_type  Lot_no  Kilometer
# 0          0     6.0      200.0
# 1          1     8.0      100.0
# 2          0     6.0    42000.0
# 3          1     8.0    51000.0
# 4          0     9.0    38000.0

# %%
X=df[['Transmission','Engine_size(cc)','Drivetrain','Fuel_type','Lot_no','Kilometer']]
X.head()
# Out:
#    Transmission  Engine_size(cc)  Drivetrain  Fuel_type  Lot_no  Kilometer
# 0             0           1150.0           0          0     6.0      200.0
# 1             1           2000.0           1          1     8.0      100.0
# 2             0           1150.0           0          0     6.0    42000.0
# 3             1           2000.0           1          1     8.0    51000.0
# 4             0           1000.0           0          0     9.0    38000.0

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(df,y,test_size=0.25,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
#predict the test data
y_pred=model.predict(X_test)
y_pred.shape
# Out:
# (476,)

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test, y_pred)
# Out:
# 1123044760819.6653

# %% [markdown]
# ###### Lets do it taking individual columns and also normalizing its values

# %%
import numpy as np 
import matplotlib.pyplot as plt 
from sklearn import preprocessing
  
def estimate_coef(x, y): 
    # number of observations/points 
    n = np.size(x) 
  
    # mean of x and y vector 
    m_x, m_y = np.mean(x), np.mean(y) 
  
    # calculating cross-deviation and deviation about x 
    SS_xy = np.sum(y*x) - n*m_y*m_x 
    SS_xx = np.sum(x*x) - n*m_x*m_x 
  
    # calculating regression coefficients 
    b_1 = SS_xy / SS_xx 
    b_0 = m_y - b_1*m_x 
  
    return(b_0, b_1) 
  
def plot_regression_line(x, y, b): 
    # plotting the actual points as scatter plot 
    plt.scatter(x, y, color = "m", 
               marker = "o", s = 30) 
  
    # predicted response vector 
    y_pred = b[0] + b[1]*x
    
    # plotting the regression line 
    plt.plot(x, y_pred, color = "g") 
  
    # putting labels 
    plt.xlabel('x') 
    plt.ylabel('y') 
  
    # function to show plot 
    plt.show()
    
def sum_square_error(y,y_pred):
    l=len(y)
    for i in range(l):
        sse=np.sum((y[i]-y_pred[i])**2)
    return sse

def total_sum_squared_error(y,m_y):
    l=len(y)
    for i in range(l):
        sst=np.sum((y[i]-m_y)**2)
    return sst

def r_squared(sse,sst):
    r=1-sse/sst
    return r

    
  
def main(): 
    # observations
     
    x = df['Engine_size(cc)']
    #x_scaled = np.log(x)
    #y_scaled = np.log(y)
    x_a=x.values.reshape(-1,1)
    y_a=y.values.reshape(-1,1)
    std_scale = preprocessing.StandardScaler().fit(x_a)
    x_scaled = std_scale.transform(x_a)
    std_scale = preprocessing.StandardScaler().fit(y_a)
    y_scaled = std_scale.transform(y_a)
                                   
    y_pred=[]
    l=len(x)
    # estimating coefficients 
    b = estimate_coef(x_scaled, y_scaled) 
    print("Estimated coefficients:\nb_0 = {}   \nb_1 = {}".format(b[0], b[1]))
    n = np.size(x)
    for i in range(n):
        y_predict = b[0] + b[1]*x_scaled
        y_pred.append(y_predict)
    m_y=np.mean(y_scaled)
    
    # plotting regression line 
    plot_regression_line(x_scaled, y_scaled, b) 
    
    #predicting sum square error
    s=sum_square_error(y_scaled,y_pred)
    print("Sum square error:",s)
    
    #predicting total sum square error
    st=total_sum_squared_error(y_scaled, m_y)
    print("Total sum square error:",st)
    
    #prdicting r_squared value
    r = r_squared(s,st)
    print("R squared value:",r)
  
if __name__ == "__main__": 
    main()
# Out:
# Estimated coefficients:
# b_0 = -2.6644235913223565e-17
# b_1 = 0.5435774379083995
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int32 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int32 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# Sum square error: 1941.3417755776643
# Total sum square error: 0.7257449133302724
# R squared value: -2673.964357199976
